# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'ind.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-indunasian.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-indunasian.pkl
# [run] => [lari]
# [who] => [siapa]
# [wow] => [wow]
# [help] => [tolong]
# [jump] => [lompat]
# [jump] => [loncat]
# [stop] => [berhenti]
# [wait] => [tunggu]
# [wait] => [tunggu]
# [hurry] => [cepatlah]
# [hurry] => [cepat]
# [hurry] => [buruan]
# [i see] => [begitu rupanya]
# [smile] => [senyum]
# [attack] => [serang]
# [cheers] => [bersulang]
# [freeze] => [jangan bergerak]
# [get up] => [bangunlah]
# [got it] => [aku mengerti]
# [got it] => [mengerti]
# [listen] => [dengar]
# [no way] => [tak bisa]
# [no way] => [tidak mungkin]
# [really] => [benarkah]
# [really] => [beneran]
# [thanks] => [terima kasih]
# [thanks] => [makasih]
# [we try] => [kami mencoba]
# [why me] => [kenapa harus saya]
# [awesome] => [mengagumkan]
# [come on] => [ayo]
# [get out] => [keluar]
# [goodbye] => [sampai jumpa]
# [hold it] => [tahan]
# [i agree] => [aku setuju]
# [im sad] => [saya sedih]
# [its ok] => [tidak apaapa]
# [its me] => [ini aku]
# [its me] => [ini aku]
# [me too] => [aku juga]
# [perfect] => [sempurna]
# [see you] => [sampai jumpa]
# [show me] => [perlihatkan padaku]
# [show me] => [perlihatin]
# [shut up] => [diam]
# [shut up] => [diamlah]
# [so long] => [sampai jumpa]
# [tom won] => [tom menang]
# [wake up] => [bangun]
# [wake up] => [bangunlah]
# [wake up] => [bangunlah]
# [welcome] => [selamat datang]
# [be still] => [jangan bergerak]
# [good job] => [kerja yang bagus]
# [good job] => [kerja bagus]
# [grab tom] => [tangkap tom]
# [hi guys] => [hai kawankawan]
# [i failed] => [aku gagal]
# [i get it] => [aku mengerti]
# [i got it] => [aku mengerti]
# [i refuse] => [aku menolak]
# [i stayed] => [aku tetap tinggal]
# [im okay] => [aku baikbaik saja]
# [its odd] => [itu aneh]
# [its odd] => [ini aneh]
# [look out] => [awas]
# [sit down] => [duduklah]
# [sit down] => [duduklah]
# [stand up] => [berdiri]
# [stand up] => [berdirilah]
# [terrific] => [hebat]
# [they won] => [mereka menang]
# [trust me] => [percaya padaku]
# [we tried] => [kami sudah mencoba]
# [what for] => [untuk apa]
# [whos he] => [dia siapa]
# [be seated] => [duduklah]
# [bless you] => [terberkatilah dirimu]
# [calm down] => [tenanglah]
# [chill out] => [tenanglah]
# [come here] => [kemari]
# [come soon] => [datanglah segera]
# [cool down] => [tenanglah]
# [dont cry] => [jangan menangis]
# [dont die] => [jangan mati]
# [fantastic] => [fantastis]
# [forget it] => [lupakan]
# [hes a dj] => [dia adalah seorang dj]
# [i can ski] => [saya bisa bermain ski]
# [i hit tom] => [aku memukul tom]
# [i mean it] => [aku serius]
# [i mean it] => [aku serius]
# [i promise] => [aku janji]
# [im a man] => [aku lakilaki]
# [im bored] => [saya bosan]
# [im bored] => [aku bosan]
# [im drunk] => [aku mabuk]
# [im first] => [aku yang pertama]
# [im naked] => [aku telanjang]
# [im tired] => [aku lelah]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-indunasian.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-indunasian-both.pkl')
save_clean_data(train, 'english-indunasian-train.pkl')
save_clean_data(test, 'english-indunasian-test.pkl')
# Out:
# Saved: english-indunasian-both.pkl
# Saved: english-indunasian-train.pkl
# Saved: english-indunasian-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-indunasian-both.pkl')
train = load_clean_sentences('english-indunasian-train.pkl')
test = load_clean_sentences('english-indunasian-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Indonasian Vocabulary Size: %d' % ger_vocab_size)
print('Indonasian Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 3647
# English Max Length: 32
# Indonasian Vocabulary Size: 4373
# Indonasian Max Length: 25
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 25, 256)           1119488
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 32, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 3647)          937279
# =================================================================
# Total params: 3,107,391
# Trainable params: 3,107,391
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 112/112 - 123s - loss: 2.1038 - val_loss: 1.3073
#
# Epoch 00001: val_loss improved from inf to 1.30726, saving model to model.h5
# Epoch 2/100
# 112/112 - 116s - loss: 1.2973 - val_loss: 1.3107
#
# Epoch 00002: val_loss did not improve from 1.30726
# Epoch 3/100
# 112/112 - 116s - loss: 1.2654 - val_loss: 1.2180
#
# Epoch 00003: val_loss improved from 1.30726 to 1.21796, saving model to model.h5
# Epoch 4/100
# 112/112 - 115s - loss: 1.2091 - val_loss: 1.1441
#
# Epoch 00004: val_loss improved from 1.21796 to 1.14406, saving model to model.h5
# Epoch 5/100
# 112/112 - 115s - loss: 1.1543 - val_loss: 1.1358
#
# Epoch 00005: val_loss improved from 1.14406 to 1.13576, saving model to model.h5
# Epoch 6/100
# 112/112 - 115s - loss: 1.1389 - val_loss: 1.1220
#
# Epoch 00006: val_loss improved from 1.13576 to 1.12197, saving model to model.h5
# Epoch 7/100
# 112/112 - 119s - loss: 1.1288 - val_loss: 1.1047
#
# Epoch 00007: val_loss improved from 1.12197 to 1.10465, saving model to model.h5
# Epoch 8/100
# 112/112 - 117s - loss: 1.1179 - val_loss: 1.0931
#
# Epoch 00008: val_loss improved from 1.10465 to 1.09307, saving model to model.h5
# Epoch 9/100
# 112/112 - 115s - loss: 1.1078 - val_loss: 1.0853
#
# Epoch 00009: val_loss improved from 1.09307 to 1.08533, saving model to model.h5
# Epoch 10/100
# 112/112 - 113s - loss: 1.1011 - val_loss: 1.0759
#
# Epoch 00010: val_loss improved from 1.08533 to 1.07586, saving model to model.h5
# Epoch 11/100
# 112/112 - 114s - loss: 1.0952 - val_loss: 1.0721
#
# Epoch 00011: val_loss improved from 1.07586 to 1.07208, saving model to model.h5
# Epoch 12/100
# 112/112 - 116s - loss: 1.0871 - val_loss: 1.0646
#
# Epoch 00012: val_loss improved from 1.07208 to 1.06465, saving model to model.h5
# Epoch 13/100
# 112/112 - 116s - loss: 1.0790 - val_loss: 1.0588
#
# Epoch 00013: val_loss improved from 1.06465 to 1.05884, saving model to model.h5
# Epoch 14/100
# 112/112 - 115s - loss: 1.0733 - val_loss: 1.0510
#
# Epoch 00014: val_loss improved from 1.05884 to 1.05102, saving model to model.h5
# Epoch 15/100
# 112/112 - 115s - loss: 1.0664 - val_loss: 1.0437
#
# Epoch 00015: val_loss improved from 1.05102 to 1.04369, saving model to model.h5
# Epoch 16/100
# 112/112 - 114s - loss: 1.0608 - val_loss: 1.0371
#
# Epoch 00016: val_loss improved from 1.04369 to 1.03708, saving model to model.h5
# Epoch 17/100
# 112/112 - 116s - loss: 1.0548 - val_loss: 1.0305
#
# Epoch 00017: val_loss improved from 1.03708 to 1.03051, saving model to model.h5
# Epoch 18/100
# 112/112 - 115s - loss: 1.0503 - val_loss: 1.0261
#
# Epoch 00018: val_loss improved from 1.03051 to 1.02613, saving model to model.h5
# Epoch 19/100
# 112/112 - 114s - loss: 1.0414 - val_loss: 1.0202
#
# Epoch 00019: val_loss improved from 1.02613 to 1.02021, saving model to model.h5
# Epoch 20/100
# 112/112 - 113s - loss: 1.0345 - val_loss: 1.0188
#
# Epoch 00020: val_loss improved from 1.02021 to 1.01876, saving model to model.h5
# Epoch 21/100
# 112/112 - 115s - loss: 1.0258 - val_loss: 1.0057
#
# Epoch 00021: val_loss improved from 1.01876 to 1.00565, saving model to model.h5
# Epoch 22/100
# 112/112 - 115s - loss: 1.0084 - val_loss: 0.9786
#
# Epoch 00022: val_loss improved from 1.00565 to 0.97865, saving model to model.h5
# Epoch 23/100
# 112/112 - 117s - loss: 0.9886 - val_loss: 0.9626
#
# Epoch 00023: val_loss improved from 0.97865 to 0.96261, saving model to model.h5
# Epoch 24/100
# 112/112 - 114s - loss: 0.9712 - val_loss: 0.9392
#
# Epoch 00024: val_loss improved from 0.96261 to 0.93921, saving model to model.h5
# Epoch 25/100
# 112/112 - 114s - loss: 0.9498 - val_loss: 0.9117
#
# Epoch 00025: val_loss improved from 0.93921 to 0.91165, saving model to model.h5
# Epoch 26/100
# 112/112 - 115s - loss: 0.9266 - val_loss: 0.8921
#
# Epoch 00026: val_loss improved from 0.91165 to 0.89206, saving model to model.h5
# Epoch 27/100
# 112/112 - 115s - loss: 0.9056 - val_loss: 0.8718
#
# Epoch 00027: val_loss improved from 0.89206 to 0.87182, saving model to model.h5
# Epoch 28/100
# 112/112 - 115s - loss: 0.8892 - val_loss: 0.8644
#
# Epoch 00028: val_loss improved from 0.87182 to 0.86440, saving model to model.h5
# Epoch 29/100
# 112/112 - 115s - loss: 0.8674 - val_loss: 0.8379
#
# Epoch 00029: val_loss improved from 0.86440 to 0.83790, saving model to model.h5
# Epoch 30/100
# 112/112 - 114s - loss: 0.8467 - val_loss: 0.8152
#
# Epoch 00030: val_loss improved from 0.83790 to 0.81518, saving model to model.h5
# Epoch 31/100
# 112/112 - 116s - loss: 0.8264 - val_loss: 0.7916
#
# Epoch 00031: val_loss improved from 0.81518 to 0.79158, saving model to model.h5
# Epoch 32/100
# 112/112 - 116s - loss: 0.8046 - val_loss: 0.7723
#
# Epoch 00032: val_loss improved from 0.79158 to 0.77228, saving model to model.h5
# Epoch 33/100
# 112/112 - 117s - loss: 0.7871 - val_loss: 0.7518
#
# Epoch 00033: val_loss improved from 0.77228 to 0.75176, saving model to model.h5
# Epoch 34/100
# 112/112 - 115s - loss: 0.7653 - val_loss: 0.7322
#
# Epoch 00034: val_loss improved from 0.75176 to 0.73217, saving model to model.h5
# Epoch 35/100
# 112/112 - 113s - loss: 0.7481 - val_loss: 0.7143
#
# Epoch 00035: val_loss improved from 0.73217 to 0.71429, saving model to model.h5
# Epoch 36/100
# 112/112 - 113s - loss: 0.7279 - val_loss: 0.6940
#
# Epoch 00036: val_loss improved from 0.71429 to 0.69404, saving model to model.h5
# Epoch 37/100
# 112/112 - 115s - loss: 0.7083 - val_loss: 0.6760
#
# Epoch 00037: val_loss improved from 0.69404 to 0.67603, saving model to model.h5
# Epoch 38/100
# 112/112 - 115s - loss: 0.6945 - val_loss: 0.6599
#
# Epoch 00038: val_loss improved from 0.67603 to 0.65988, saving model to model.h5
# Epoch 39/100
# 112/112 - 115s - loss: 0.6726 - val_loss: 0.6388
#
# Epoch 00039: val_loss improved from 0.65988 to 0.63877, saving model to model.h5
# Epoch 40/100
# 112/112 - 114s - loss: 0.6516 - val_loss: 0.6156
#
# Epoch 00040: val_loss improved from 0.63877 to 0.61564, saving model to model.h5
# Epoch 41/100
# 112/112 - 114s - loss: 0.6330 - val_loss: 0.5973
#
# Epoch 00041: val_loss improved from 0.61564 to 0.59733, saving model to model.h5
# Epoch 42/100
# 112/112 - 117s - loss: 0.6156 - val_loss: 0.5829
#
# Epoch 00042: val_loss improved from 0.59733 to 0.58287, saving model to model.h5
# Epoch 43/100
# 112/112 - 115s - loss: 0.6003 - val_loss: 0.5634
#
# Epoch 00043: val_loss improved from 0.58287 to 0.56340, saving model to model.h5
# Epoch 44/100
# 112/112 - 116s - loss: 0.5801 - val_loss: 0.5450
#
# Epoch 00044: val_loss improved from 0.56340 to 0.54501, saving model to model.h5
# Epoch 45/100
# 112/112 - 117s - loss: 0.5639 - val_loss: 0.5297
#
# Epoch 00045: val_loss improved from 0.54501 to 0.52972, saving model to model.h5
# Epoch 46/100
# 112/112 - 114s - loss: 0.5464 - val_loss: 0.5134
#
# Epoch 00046: val_loss improved from 0.52972 to 0.51339, saving model to model.h5
# Epoch 47/100
# 112/112 - 115s - loss: 0.5300 - val_loss: 0.4974
#
# Epoch 00047: val_loss improved from 0.51339 to 0.49736, saving model to model.h5
# Epoch 48/100
# 112/112 - 115s - loss: 0.5150 - val_loss: 0.4846
#
# Epoch 00048: val_loss improved from 0.49736 to 0.48456, saving model to model.h5
# Epoch 49/100
# 112/112 - 115s - loss: 0.4985 - val_loss: 0.4670
#
# Epoch 00049: val_loss improved from 0.48456 to 0.46695, saving model to model.h5
# Epoch 50/100
# 112/112 - 114s - loss: 0.4826 - val_loss: 0.4503
#
# Epoch 00050: val_loss improved from 0.46695 to 0.45034, saving model to model.h5
# Epoch 51/100
# 112/112 - 113s - loss: 0.4670 - val_loss: 0.4423
#
# Epoch 00051: val_loss improved from 0.45034 to 0.44233, saving model to model.h5
# Epoch 52/100
# 112/112 - 113s - loss: 0.4533 - val_loss: 0.4254
#
# Epoch 00052: val_loss improved from 0.44233 to 0.42542, saving model to model.h5
# Epoch 53/100
# 112/112 - 116s - loss: 0.4377 - val_loss: 0.4101
#
# Epoch 00053: val_loss improved from 0.42542 to 0.41007, saving model to model.h5
# Epoch 54/100
# 112/112 - 115s - loss: 0.4236 - val_loss: 0.4015
#
# Epoch 00054: val_loss improved from 0.41007 to 0.40153, saving model to model.h5
# Epoch 55/100
# 112/112 - 115s - loss: 0.4103 - val_loss: 0.3874
#
# Epoch 00055: val_loss improved from 0.40153 to 0.38736, saving model to model.h5
# Epoch 56/100
# 112/112 - 115s - loss: 0.3989 - val_loss: 0.3724
#
# Epoch 00056: val_loss improved from 0.38736 to 0.37239, saving model to model.h5
# Epoch 57/100
# 112/112 - 113s - loss: 0.3858 - val_loss: 0.3595
#
# Epoch 00057: val_loss improved from 0.37239 to 0.35954, saving model to model.h5
# Epoch 58/100
# 112/112 - 114s - loss: 0.3725 - val_loss: 0.3543
#
# Epoch 00058: val_loss improved from 0.35954 to 0.35434, saving model to model.h5
# Epoch 59/100
# 112/112 - 115s - loss: 0.3591 - val_loss: 0.3328
#
# Epoch 00059: val_loss improved from 0.35434 to 0.33283, saving model to model.h5
# Epoch 60/100
# 112/112 - 114s - loss: 0.3460 - val_loss: 0.3230
#
# Epoch 00060: val_loss improved from 0.33283 to 0.32297, saving model to model.h5
# Epoch 61/100
# 112/112 - 115s - loss: 0.3356 - val_loss: 0.3131
#
# Epoch 00061: val_loss improved from 0.32297 to 0.31307, saving model to model.h5
# Epoch 62/100
# 112/112 - 114s - loss: 0.3259 - val_loss: 0.3020
#
# Epoch 00062: val_loss improved from 0.31307 to 0.30200, saving model to model.h5
# Epoch 63/100
# 112/112 - 114s - loss: 0.3143 - val_loss: 0.2950
#
# Epoch 00063: val_loss improved from 0.30200 to 0.29495, saving model to model.h5
# Epoch 64/100
# 112/112 - 115s - loss: 0.3057 - val_loss: 0.2848
#
# Epoch 00064: val_loss improved from 0.29495 to 0.28485, saving model to model.h5
# Epoch 65/100
# 112/112 - 114s - loss: 0.2944 - val_loss: 0.2728
#
# Epoch 00065: val_loss improved from 0.28485 to 0.27279, saving model to model.h5
# Epoch 66/100
# 112/112 - 114s - loss: 0.2868 - val_loss: 0.2713
#
# Epoch 00066: val_loss improved from 0.27279 to 0.27130, saving model to model.h5
# Epoch 67/100
# 112/112 - 116s - loss: 0.2827 - val_loss: 0.2571
#
# Epoch 00067: val_loss improved from 0.27130 to 0.25706, saving model to model.h5
# Epoch 68/100
# 112/112 - 114s - loss: 0.2671 - val_loss: 0.2429
#
# Epoch 00068: val_loss improved from 0.25706 to 0.24292, saving model to model.h5
# Epoch 69/100
# 112/112 - 114s - loss: 0.2547 - val_loss: 0.2355
#
# Epoch 00069: val_loss improved from 0.24292 to 0.23550, saving model to model.h5
# Epoch 70/100
# 112/112 - 115s - loss: 0.2441 - val_loss: 0.2242
#
# Epoch 00070: val_loss improved from 0.23550 to 0.22423, saving model to model.h5
# Epoch 71/100
# 112/112 - 113s - loss: 0.2358 - val_loss: 0.2217
#
# Epoch 00071: val_loss improved from 0.22423 to 0.22166, saving model to model.h5
# Epoch 72/100
# 112/112 - 113s - loss: 0.2292 - val_loss: 0.2103
#
# Epoch 00072: val_loss improved from 0.22166 to 0.21031, saving model to model.h5
# Epoch 73/100
# 112/112 - 114s - loss: 0.2205 - val_loss: 0.2050
#
# Epoch 00073: val_loss improved from 0.21031 to 0.20496, saving model to model.h5
# Epoch 74/100
# 112/112 - 114s - loss: 0.2168 - val_loss: 0.2010
#
# Epoch 00074: val_loss improved from 0.20496 to 0.20103, saving model to model.h5
# Epoch 75/100
# 112/112 - 113s - loss: 0.2125 - val_loss: 0.1932
#
# Epoch 00075: val_loss improved from 0.20103 to 0.19316, saving model to model.h5
# Epoch 76/100
# 112/112 - 114s - loss: 0.2030 - val_loss: 0.1867
#
# Epoch 00076: val_loss improved from 0.19316 to 0.18666, saving model to model.h5
# Epoch 77/100
# 112/112 - 113s - loss: 0.1953 - val_loss: 0.1794
#
# Epoch 00077: val_loss improved from 0.18666 to 0.17943, saving model to model.h5
# Epoch 78/100
# 112/112 - 114s - loss: 0.1868 - val_loss: 0.1728
#
# Epoch 00078: val_loss improved from 0.17943 to 0.17276, saving model to model.h5
# Epoch 79/100
# 112/112 - 114s - loss: 0.1799 - val_loss: 0.1664
#
# Epoch 00079: val_loss improved from 0.17276 to 0.16640, saving model to model.h5
# Epoch 80/100
# 112/112 - 113s - loss: 0.1728 - val_loss: 0.1579
#
# Epoch 00080: val_loss improved from 0.16640 to 0.15790, saving model to model.h5
# Epoch 81/100
# 112/112 - 114s - loss: 0.1669 - val_loss: 0.1553
#
# Epoch 00081: val_loss improved from 0.15790 to 0.15528, saving model to model.h5
# Epoch 82/100
# 112/112 - 113s - loss: 0.1609 - val_loss: 0.1488
#
# Epoch 00082: val_loss improved from 0.15528 to 0.14877, saving model to model.h5
# Epoch 83/100
# 112/112 - 113s - loss: 0.1575 - val_loss: 0.1432
#
# Epoch 00083: val_loss improved from 0.14877 to 0.14321, saving model to model.h5
# Epoch 84/100
# 112/112 - 114s - loss: 0.1548 - val_loss: 0.1441
#
# Epoch 00084: val_loss did not improve from 0.14321
# Epoch 85/100
# 112/112 - 114s - loss: 0.1514 - val_loss: 0.1386
#
# Epoch 00085: val_loss improved from 0.14321 to 0.13864, saving model to model.h5
# Epoch 86/100
# 112/112 - 114s - loss: 0.1454 - val_loss: 0.1344
#
# Epoch 00086: val_loss improved from 0.13864 to 0.13442, saving model to model.h5
# Epoch 87/100
# 112/112 - 115s - loss: 0.1411 - val_loss: 0.1283
#
# Epoch 00087: val_loss improved from 0.13442 to 0.12830, saving model to model.h5
# Epoch 88/100
# 112/112 - 115s - loss: 0.1352 - val_loss: 0.1215
#
# Epoch 00088: val_loss improved from 0.12830 to 0.12145, saving model to model.h5
# Epoch 89/100
# 112/112 - 113s - loss: 0.1286 - val_loss: 0.1170
#
# Epoch 00089: val_loss improved from 0.12145 to 0.11697, saving model to model.h5
# Epoch 90/100
# 112/112 - 114s - loss: 0.1232 - val_loss: 0.1159
#
# Epoch 00090: val_loss improved from 0.11697 to 0.11585, saving model to model.h5
# Epoch 91/100
# 112/112 - 114s - loss: 0.1201 - val_loss: 0.1086
#
# Epoch 00091: val_loss improved from 0.11585 to 0.10862, saving model to model.h5
# Epoch 92/100
# 112/112 - 114s - loss: 0.1158 - val_loss: 0.1061
#
# Epoch 00092: val_loss improved from 0.10862 to 0.10615, saving model to model.h5
# Epoch 93/100
# 112/112 - 116s - loss: 0.1124 - val_loss: 0.1009
#
# Epoch 00093: val_loss improved from 0.10615 to 0.10088, saving model to model.h5
# Epoch 94/100
# 112/112 - 115s - loss: 0.1071 - val_loss: 0.0991
#
# Epoch 00094: val_loss improved from 0.10088 to 0.09911, saving model to model.h5
# Epoch 95/100
# 112/112 - 116s - loss: 0.1036 - val_loss: 0.0955
#
# Epoch 00095: val_loss improved from 0.09911 to 0.09548, saving model to model.h5
# Epoch 96/100
# 112/112 - 115s - loss: 0.1004 - val_loss: 0.0917
#
# Epoch 00096: val_loss improved from 0.09548 to 0.09171, saving model to model.h5
# Epoch 97/100
# 112/112 - 114s - loss: 0.0970 - val_loss: 0.0911
#
# Epoch 00097: val_loss improved from 0.09171 to 0.09109, saving model to model.h5
# Epoch 98/100
# 112/112 - 114s - loss: 0.1104 - val_loss: 0.1018
#
# Epoch 00098: val_loss did not improve from 0.09109
# Epoch 99/100
# 112/112 - 114s - loss: 0.1082 - val_loss: 0.0945
#
# Epoch 00099: val_loss did not improve from 0.09109
# Epoch 100/100
# 112/112 - 114s - loss: 0.0965 - val_loss: 0.0866
#
# Epoch 00100: val_loss improved from 0.09109 to 0.08657, saving model to model.h5

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,train = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-indunasian-both.pkl')
train = load_clean_sentences('english-indunasian-train.pkl')
test = load_clean_sentences('english-indunasian-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[itu adalah lelucon terlucu yang pernah saya dengar], target=[that is the funniest joke that i have ever heard], predicted=[that is the funniest joke that i ever ever heard]
# src=[kamu bisa mengandalkan bantuannya], target=[you can depend on his help], predicted=[you can depend on his help]
# src=[tom tidak lagi diundang ke pesta], target=[tom doesnt get invited to parties anymore], predicted=[tom doesnt invited invited to parties anymore]
# src=[sejumlah uang telah dicuri], target=[some of the money was stolen], predicted=[some of the money was stolen]
# src=[tom melempar kaleng sodanya ke dalam tong sampah], target=[tom tossed the soda can into the trash], predicted=[tom tossed the soda can into the trash]
# src=[itulah yang sedang saya lakukan tadi], target=[thats what i was doing], predicted=[thats what i was doing]
# src=[itulah yang membuatku tertarik], target=[thats what interests me], predicted=[thats what interests me]
# src=[dikatakan bahwa bangsa viking lebih dulu menemukan benua amerika sebelum columbus], target=[its said that the vikings discovered america before columbus did], predicted=[its said that the vikings discovered america america columbus columbus]
# src=[tepat sekali], target=[thats right], predicted=[thats right]
# src=[tom sangat membutuhkan bantuan], target=[tom needs all the help he can get], predicted=[tom needs all the help he]
# BLEU-1: 0.907693
# BLEU-2: 0.861128
# BLEU-3: 0.832012
# BLEU-4: 0.765514
# test
# src=[tom tidak pernah membawa siapasiapa kemari], target=[tom never brought anyone here], predicted=[tom never brought anyone here]
# src=[ini agak aneh], target=[its rather curious], predicted=[its rather curious]
# src=[apa kau punya susu], target=[do you have some milk], predicted=[do you have some milk]
# src=[bisakah kita pergi ke sirkus], target=[can we go to the circus], predicted=[can we go to to circus circus]
# src=[apakah kamu membuat sendiri boneka ini], target=[did you make this doll by yourself], predicted=[did you make this doll by yourself]
# src=[debatnya berlanjut], target=[the debate is continuing], predicted=[the debate is continuing]
# src=[anak lakilaki itu melompat], target=[the boy is jumping], predicted=[the boy is jumping]
# src=[stasiun kereta ada di mana], target=[where is the railroad station], predicted=[where is the railway station]
# src=[kita harus melakukan sesuatu], target=[weve got to do something], predicted=[we have to do something]
# src=[saya tidak mengira itu benar], target=[i dont think thats true], predicted=[i dont think thats true]
# BLEU-1: 0.907563
# BLEU-2: 0.860759
# BLEU-3: 0.831755
# BLEU-4: 0.765196

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-indunasian-both.pkl')
train = load_clean_sentences('english-indunasian-train.pkl')
test = load_clean_sentences('english-indunasian-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[itu adalah lelucon terlucu yang pernah saya dengar], target=[that is the funniest joke that i have ever heard], predicted=[that is the funniest joke that i ever ever heard]
# src=[kamu bisa mengandalkan bantuannya], target=[you can depend on his help], predicted=[you can depend on his help]
# src=[tom tidak lagi diundang ke pesta], target=[tom doesnt get invited to parties anymore], predicted=[tom doesnt invited invited to parties anymore]
# src=[sejumlah uang telah dicuri], target=[some of the money was stolen], predicted=[some of the money was stolen]
# src=[tom melempar kaleng sodanya ke dalam tong sampah], target=[tom tossed the soda can into the trash], predicted=[tom tossed the soda can into the trash]
# src=[itulah yang sedang saya lakukan tadi], target=[thats what i was doing], predicted=[thats what i was doing]
# src=[itulah yang membuatku tertarik], target=[thats what interests me], predicted=[thats what interests me]
# src=[dikatakan bahwa bangsa viking lebih dulu menemukan benua amerika sebelum columbus], target=[its said that the vikings discovered america before columbus did], predicted=[its said that the vikings discovered america america columbus columbus]
# src=[tepat sekali], target=[thats right], predicted=[thats right]
# src=[tom sangat membutuhkan bantuan], target=[tom needs all the help he can get], predicted=[tom needs all the help he]
# BLEU-1: 0.907693
# BLEU-2: 0.861128
# BLEU-3: 0.832012
# BLEU-4: 0.765514
# test
# src=[tom tidak pernah membawa siapasiapa kemari], target=[tom never brought anyone here], predicted=[tom never brought anyone here]
# src=[ini agak aneh], target=[its rather curious], predicted=[its rather curious]
# src=[apa kau punya susu], target=[do you have some milk], predicted=[do you have some milk]
# src=[bisakah kita pergi ke sirkus], target=[can we go to the circus], predicted=[can we go to to circus circus]
# src=[apakah kamu membuat sendiri boneka ini], target=[did you make this doll by yourself], predicted=[did you make this doll by yourself]
# src=[debatnya berlanjut], target=[the debate is continuing], predicted=[the debate is continuing]
# src=[anak lakilaki itu melompat], target=[the boy is jumping], predicted=[the boy is jumping]
# src=[stasiun kereta ada di mana], target=[where is the railroad station], predicted=[where is the railway station]
# src=[kita harus melakukan sesuatu], target=[weve got to do something], predicted=[we have to do something]
# src=[saya tidak mengira itu benar], target=[i dont think thats true], predicted=[i dont think thats true]
# BLEU-1: 0.907563
# BLEU-2: 0.860759
# BLEU-3: 0.831755
# BLEU-4: 0.765196
